# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Library import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Parameter definition

# %%
RAW_DATA = '../data/raw/' 
EXTERNAL_DATA = '../data/external/' 
INTERIM_DATA = '../data/interim/' 
PROCESSED_DATA = '../data/processed/'
REFERENCES = '../references/'
RANDOM_STATE = 14

# %% [markdown]
# ## Read data

# %%
df = pd.read_parquet(INTERIM_DATA + 'train.pqt')
df.head()
# Out:
#          Category                      Descript  DayOfWeek PdDistrict  \
# 0        WARRANTS                WARRANT ARREST  Wednesday   NORTHERN
# 1  OTHER OFFENSES      TRAFFIC VIOLATION ARREST  Wednesday   NORTHERN
# 2  OTHER OFFENSES      TRAFFIC VIOLATION ARREST  Wednesday   NORTHERN
# 3   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO  Wednesday   NORTHERN
# 4   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO  Wednesday       PARK
#
#        Resolution                    Address           X          Y  month  \
# 0  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892  37.774599      5
# 1  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892  37.774599      5
# 2  ARREST, BOOKED  VANNESS AV / GREENWICH ST -122.424363  37.800414      5
# 3            NONE   1500 Block of LOMBARD ST -122.426995  37.800873      5
# 4            NONE  100 Block of BRODERICK ST -122.438738  37.771541      5
#
#    day  year  hour
# 0   13  2015    23
# 1   13  2015    23
# 2   13  2015    23
# 3   13  2015    23
# 4   13  2015    23

# %% [markdown]
# ## First attempt

# %% [markdown]
# In the first attempt, which will became the baseline, I won't make any data preparation.

# %%
df_1 = df.copy()

# %%
df_1.to_parquet(PROCESSED_DATA + 'train_1.pqt', index=False)

# %% [markdown]
# ## Second attempt

# %% [markdown]
# For this attempt I will:
#  - Drop all duplicated rows
#  - Create column "weekend" that shows if the crime happened during the week or the weekend

# %%
df_2 = df_1.copy()

# %%
df_2.duplicated().sum()
# Out:
# 4658

# %%
df_2.drop_duplicates(keep='first', inplace=True)
df_2
# Out:
#                       Category                                   Descript  \
# 0                     WARRANTS                             WARRANT ARREST
# 1               OTHER OFFENSES                   TRAFFIC VIOLATION ARREST
# 2               OTHER OFFENSES                   TRAFFIC VIOLATION ARREST
# 3                LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 4                LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# ...                        ...                                        ...
# 878044                 ROBBERY           ROBBERY ON THE STREET WITH A GUN
# 878045           LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 878046           LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 878047               VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES
# 878048  FORGERY/COUNTERFEITING                   CHECKS, FORGERY (FELONY)
#
#         DayOfWeek PdDistrict      Resolution                     Address  \
# 0       Wednesday   NORTHERN  ARREST, BOOKED          OAK ST / LAGUNA ST
# 1       Wednesday   NORTHERN  ARREST, BOOKED          OAK ST / LAGUNA ST
# 2       Wednesday   NORTHERN  ARREST, BOOKED   VANNESS AV / GREENWICH ST
# 3       Wednesday   NORTHERN            NONE    1500 Block of LOMBARD ST
# 4       Wednesday       PARK            NONE   100 Block of BRODERICK ST
# ...           ...        ...             ...                         ...
# 878044     Monday    TARAVAL            NONE  FARALLONES ST / CAPITOL AV
# 878045     Monday  INGLESIDE            NONE        600 Block of EDNA ST
# 878046     Monday   SOUTHERN            NONE          5TH ST / FOLSOM ST
# 878047     Monday   SOUTHERN            NONE        TOWNSEND ST / 2ND ST
# 878048     Monday    BAYVIEW            NONE    1800 Block of NEWCOMB AV
#
#                  X          Y  month  day  year  hour
# 0      -122.425892  37.774599      5   13  2015    23
# 1      -122.425892  37.774599      5   13  2015    23
# 2      -122.424363  37.800414      5   13  2015    23
# 3      -122.426995  37.800873      5   13  2015    23
# 4      -122.438738  37.771541      5   13  2015    23
# ...            ...        ...    ...  ...   ...   ...
# 878044 -122.459033  37.714056      1    6  2003     0
# 878045 -122.447364  37.731948      1    6  2003     0
# 878046 -122.403390  37.780266      1    6  2003     0
# 878047 -122.390531  37.780607      1    6  2003     0
# 878048 -122.394926  37.738212      1    6  2003     0
#
# [873391 rows x 12 columns]

# %%
df_2['Weekend'] = np.where((df_2['DayOfWeek']=='Sunday')|(df_2['DayOfWeek']=='Saturday'), 1, 0)
df_2.head(100)
# Out:
#            Category                                     Descript  DayOfWeek  \
# 0          WARRANTS                               WARRANT ARREST  Wednesday
# 1    OTHER OFFENSES                     TRAFFIC VIOLATION ARREST  Wednesday
# 2    OTHER OFFENSES                     TRAFFIC VIOLATION ARREST  Wednesday
# 3     LARCENY/THEFT                 GRAND THEFT FROM LOCKED AUTO  Wednesday
# 4     LARCENY/THEFT                 GRAND THEFT FROM LOCKED AUTO  Wednesday
# ..              ...                                          ...        ...
# 96   OTHER OFFENSES                            TRAFFIC VIOLATION  Wednesday
# 97         BURGLARY  BURGLARY OF APARTMENT HOUSE, UNLAWFUL ENTRY  Wednesday
# 98    LARCENY/THEFT               GRAND THEFT FROM UNLOCKED AUTO  Wednesday
# 99    LARCENY/THEFT                 GRAND THEFT FROM LOCKED AUTO  Wednesday
# 100   LARCENY/THEFT                 GRAND THEFT FROM LOCKED AUTO  Wednesday
#
#     PdDistrict      Resolution                    Address           X  \
# 0     NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 1     NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 2     NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST -122.424363
# 3     NORTHERN            NONE   1500 Block of LOMBARD ST -122.426995
# 4         PARK            NONE  100 Block of BRODERICK ST -122.438738
# ..         ...             ...                        ...         ...
# 96     MISSION  ARREST, BOOKED      25TH ST / SHOTWELL ST -122.415015
# 97    SOUTHERN            NONE          0 Block of 6TH ST -122.409504
# 98     BAYVIEW            NONE      ILLINOIS ST / 20TH ST -122.387571
# 99        PARK            NONE        CASTRO ST / 16TH ST -122.435318
# 100       PARK            NONE        COLE ST / FULTON ST -122.451360
#
#              Y  month  day  year  hour  Weekend
# 0    37.774599      5   13  2015    23        0
# 1    37.774599      5   13  2015    23        0
# 2    37.800414      5   13  2015    23        0
# 3    37.800873      5   13  2015    23        0
# 4    37.771541      5   13  2015    23        0
# ..         ...    ...  ...   ...   ...      ...
# 96   37.750836      5   13  2015    18        0
# 97   37.781526      5   13  2015    18        0
# 98   37.760550      5   13  2015    18        0
# 99   37.764102      5   13  2015    18        0
# 100  37.775174      5   13  2015    18        0
#
# [100 rows x 13 columns]

# %%
df_2.to_parquet(PROCESSED_DATA + 'train_2.pqt', index=False)

# %% [markdown]
# ## Third attempt

# %% [markdown]
# For this attempt I will:
#  - Create column "day_period" that shows if the crime happened during dawn, morning, afternoon or night

# %%
df_3 = df_2.copy()

# %%
#Creating morning, afternoon, night and dawn
condlist = [df_3['hour']<6, df_3['hour']<12, df_3['hour']<18]
choicelist = ['dawn', 'morning', 'afternoon']
df_3['day_period'] = np.select(condlist, choicelist, 'night')
df_3['day_period'].value_counts()
# Out:
# afternoon    289873
# night        279411
# morning      178794
# dawn         125313
# Name: day_period, dtype: int64

# %%
df_3.to_parquet(PROCESSED_DATA + 'train_3.pqt', index=False)

# %%
df_3
# Out:
#                       Category                                   Descript  \
# 0                     WARRANTS                             WARRANT ARREST
# 1               OTHER OFFENSES                   TRAFFIC VIOLATION ARREST
# 2               OTHER OFFENSES                   TRAFFIC VIOLATION ARREST
# 3                LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 4                LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# ...                        ...                                        ...
# 878044                 ROBBERY           ROBBERY ON THE STREET WITH A GUN
# 878045           LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 878046           LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 878047               VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES
# 878048  FORGERY/COUNTERFEITING                   CHECKS, FORGERY (FELONY)
#
#         DayOfWeek PdDistrict      Resolution                     Address  \
# 0       Wednesday   NORTHERN  ARREST, BOOKED          OAK ST / LAGUNA ST
# 1       Wednesday   NORTHERN  ARREST, BOOKED          OAK ST / LAGUNA ST
# 2       Wednesday   NORTHERN  ARREST, BOOKED   VANNESS AV / GREENWICH ST
# 3       Wednesday   NORTHERN            NONE    1500 Block of LOMBARD ST
# 4       Wednesday       PARK            NONE   100 Block of BRODERICK ST
# ...           ...        ...             ...                         ...
# 878044     Monday    TARAVAL            NONE  FARALLONES ST / CAPITOL AV
# 878045     Monday  INGLESIDE            NONE        600 Block of EDNA ST
# 878046     Monday   SOUTHERN            NONE          5TH ST / FOLSOM ST
# 878047     Monday   SOUTHERN            NONE        TOWNSEND ST / 2ND ST
# 878048     Monday    BAYVIEW            NONE    1800 Block of NEWCOMB AV
#
#                  X          Y  month  day  year  hour  Weekend day_period
# 0      -122.425892  37.774599      5   13  2015    23        0      night
# 1      -122.425892  37.774599      5   13  2015    23        0      night
# 2      -122.424363  37.800414      5   13  2015    23        0      night
# 3      -122.426995  37.800873      5   13  2015    23        0      night
# 4      -122.438738  37.771541      5   13  2015    23        0      night
# ...            ...        ...    ...  ...   ...   ...      ...        ...
# 878044 -122.459033  37.714056      1    6  2003     0        0       dawn
# 878045 -122.447364  37.731948      1    6  2003     0        0       dawn
# 878046 -122.403390  37.780266      1    6  2003     0        0       dawn
# 878047 -122.390531  37.780607      1    6  2003     0        0       dawn
# 878048 -122.394926  37.738212      1    6  2003     0        0       dawn
#
# [873391 rows x 14 columns]

# %% [markdown]
# ## Fourth attempt

# %% [markdown]
# For this attempt I will:
#  - Replace outliers longitude and latitude for mode values

# %%
df_4 = df_3.copy()
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873391 entries, 0 to 878048
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Category    873391 non-null  object
#  1   Descript    873391 non-null  object
#  2   DayOfWeek   873391 non-null  object
#  3   PdDistrict  873391 non-null  object
#  4   Resolution  873391 non-null  object
#  5   Address     873391 non-null  object
#  6   X           873391 non-null  float64
#  7   Y           873391 non-null  float64
#  8   month       873391 non-null  int64
#  9   day         873391 non-null  int64
#  10  year        873391 non-null  int64
#  11  hour        873391 non-null  int64
#  12  Weekend     873391 non-null  int32
#  13  day_period  873391 non-null  object
# dtypes: float64(2), int32(1), int64(4), object(7)
# memory usage: 96.6+ MB

# %%
#df_4 = df.copy()
outliers = (df['X'] > -122.35)|(df['Y'] > 37.82)
df_4.loc[outliers, ['X', 'Y']] = np.nan
#df.info()
outliers.value_counts()
# Out:
# False    877982
# True         67
# dtype: int64

# %%
df_4.query('X>-122')
# Out:
# Empty DataFrame
# Columns: [Category, Descript, DayOfWeek, PdDistrict, Resolution, Address, X, Y, month, day, year, hour, Weekend, day_period]
# Index: []

# %%
df_4.to_parquet(PROCESSED_DATA + 'train_4.pqt', index=False)

# %%
df_4
# Out:
#                       Category                                   Descript  \
# 0                     WARRANTS                             WARRANT ARREST
# 1               OTHER OFFENSES                   TRAFFIC VIOLATION ARREST
# 2               OTHER OFFENSES                   TRAFFIC VIOLATION ARREST
# 3                LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 4                LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# ...                        ...                                        ...
# 878044                 ROBBERY           ROBBERY ON THE STREET WITH A GUN
# 878045           LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 878046           LARCENY/THEFT               GRAND THEFT FROM LOCKED AUTO
# 878047               VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES
# 878048  FORGERY/COUNTERFEITING                   CHECKS, FORGERY (FELONY)
#
#         DayOfWeek PdDistrict      Resolution                     Address  \
# 0       Wednesday   NORTHERN  ARREST, BOOKED          OAK ST / LAGUNA ST
# 1       Wednesday   NORTHERN  ARREST, BOOKED          OAK ST / LAGUNA ST
# 2       Wednesday   NORTHERN  ARREST, BOOKED   VANNESS AV / GREENWICH ST
# 3       Wednesday   NORTHERN            NONE    1500 Block of LOMBARD ST
# 4       Wednesday       PARK            NONE   100 Block of BRODERICK ST
# ...           ...        ...             ...                         ...
# 878044     Monday    TARAVAL            NONE  FARALLONES ST / CAPITOL AV
# 878045     Monday  INGLESIDE            NONE        600 Block of EDNA ST
# 878046     Monday   SOUTHERN            NONE          5TH ST / FOLSOM ST
# 878047     Monday   SOUTHERN            NONE        TOWNSEND ST / 2ND ST
# 878048     Monday    BAYVIEW            NONE    1800 Block of NEWCOMB AV
#
#                  X          Y  month  day  year  hour  Weekend day_period
# 0      -122.425892  37.774599      5   13  2015    23        0      night
# 1      -122.425892  37.774599      5   13  2015    23        0      night
# 2      -122.424363  37.800414      5   13  2015    23        0      night
# 3      -122.426995  37.800873      5   13  2015    23        0      night
# 4      -122.438738  37.771541      5   13  2015    23        0      night
# ...            ...        ...    ...  ...   ...   ...      ...        ...
# 878044 -122.459033  37.714056      1    6  2003     0        0       dawn
# 878045 -122.447364  37.731948      1    6  2003     0        0       dawn
# 878046 -122.403390  37.780266      1    6  2003     0        0       dawn
# 878047 -122.390531  37.780607      1    6  2003     0        0       dawn
# 878048 -122.394926  37.738212      1    6  2003     0        0       dawn
#
# [873391 rows x 14 columns]
